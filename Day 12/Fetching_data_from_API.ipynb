# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/trending/movie/week?api_key=d3f601db79d3e6403feca10f9b0921d6')

# %%
response.json()

# %%
df = pd.DataFrame(response.json()['results'])
df

# %% [markdown]
# # convert to csv files

# %%
df.to_csv('movies.csv')
